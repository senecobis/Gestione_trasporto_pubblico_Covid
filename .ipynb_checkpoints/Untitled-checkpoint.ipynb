# %%
In [1]: import numpy as np
In [2]: import pandas as pd

# %% [markdown]
# porzioni_viaggio = pd.read_excel('file di dati.xls', sheet_name='porzioni di viaggio')
# tempi_vuoto = pd.read_excel('file di dati.xls', sheet_name='tempi di percorrenza a vuoto')

# %%
porzioni_viaggio = pd.read_excel('file di dati.xls', sheet_name='porzioni di viaggio')
tempi_vuoto = pd.read_excel('file di dati.xls', sheet_name='tempi di percorrenza a vuoto')

# %%
x = porzioni_viaggio.to_numpy()
print(x)
# Out:
# [['counted passengers' 'extra passengers' 'initial stop' 'final stop'
#   'initial time' 'final time']
#  [70 20 'stazione' 'medaglie d’oro'
#   datetime.datetime(2020, 11, 27, 7, 10)
#   datetime.datetime(2020, 11, 27, 7, 21)]
#  [60 20 'stazione' 'medaglie d’oro'
#   datetime.datetime(2020, 11, 27, 7, 24)
#   datetime.datetime(2020, 11, 27, 7, 35)]
#  [97 47 'medaglie d’oro' 'stazione'
#   datetime.datetime(2020, 11, 27, 7, 27)
#   datetime.datetime(2020, 11, 27, 7, 38)]
#  [107 57 'cavour giardini' 'ospedale'
#   datetime.datetime(2020, 11, 27, 7, 30)
#   datetime.datetime(2020, 11, 27, 7, 58)]
#  [68 28 'medaglie d’oro' 'stazione'
#   datetime.datetime(2020, 11, 27, 7, 35)
#   datetime.datetime(2020, 11, 27, 7, 46)]
#  [60 20 'stazione' 'kennedy' datetime.datetime(2020, 11, 27, 7, 36)
#   datetime.datetime(2020, 11, 27, 7, 44)]
#  [70 30 'stazione' 'p. dante' datetime.datetime(2020, 11, 27, 7, 40)
#   datetime.datetime(2020, 11, 27, 7, 46)]
#  [125 75 'stazione' 'medaglie d’oro'
#   datetime.datetime(2020, 11, 27, 7, 40)
#   datetime.datetime(2020, 11, 27, 7, 51)]
#  [90 40 'medaglie d’oro' 'stazione'
#   datetime.datetime(2020, 11, 27, 7, 50)
#   datetime.datetime(2020, 11, 27, 8, 1)]
#  [74 34 'stazione' 'p. dante' datetime.datetime(2020, 11, 27, 7, 55)
#   datetime.datetime(2020, 11, 27, 8, 1)]
#  [191 141 'stazione' 'medaglie d’oro'
#   datetime.datetime(2020, 11, 27, 7, 55)
#   datetime.datetime(2020, 11, 27, 8, 6)]
#  [84 34 'cavour giardini' 'ospedale'
#   datetime.datetime(2020, 11, 27, 8, 18)
#   datetime.datetime(2020, 11, 27, 8, 46)]
#  [65 15 'cavour giardini' 'ospedale'
#   datetime.datetime(2020, 11, 27, 8, 20)
#   datetime.datetime(2020, 11, 27, 8, 53)]
#  [87 37 'stazione' 'ospedale' datetime.datetime(2020, 11, 27, 8, 30)
#   datetime.datetime(2020, 11, 27, 9, 3)]
#  [62 12 'stazione' 'medaglie d’oro'
#   datetime.datetime(2020, 11, 27, 8, 45)
#   datetime.datetime(2020, 11, 27, 8, 56)]
#  [80 30 'cavour giardini' 'ospedale'
#   datetime.datetime(2020, 11, 27, 9, 5)
#   datetime.datetime(2020, 11, 27, 9, 33)]
#  [67 17 'cavour giardini' 'ospedale'
#   datetime.datetime(2020, 11, 27, 9, 20)
#   datetime.datetime(2020, 11, 27, 9, 53)]
#  [88 38 'cavour giardini' 'ospedale'
#   datetime.datetime(2020, 11, 27, 9, 50)
#   datetime.datetime(2020, 11, 27, 10, 18)]
#  [61 11 'medaglie d’oro' 'stazione'
#   datetime.datetime(2020, 11, 27, 10, 20)
#   datetime.datetime(2020, 11, 27, 10, 31)]
#  [68 18 'cavour giardini' 'ospedale'
#   datetime.datetime(2020, 11, 27, 11, 5)
#   datetime.datetime(2020, 11, 27, 11, 33)]
#  [64 14 'ospedale' 'medaglie d’oro'
#   datetime.datetime(2020, 11, 27, 11, 23)
#   datetime.datetime(2020, 11, 27, 11, 50)]
#  [73 23 'medaglie d’oro' 'stazione'
#   datetime.datetime(2020, 11, 27, 12, 5)
#   datetime.datetime(2020, 11, 27, 12, 16)]
#  [75 25 'medaglie d’oro' 'stazione'
#   datetime.datetime(2020, 11, 27, 12, 20)
#   datetime.datetime(2020, 11, 27, 12, 31)]
#  [65 15 'medaglie d’oro' 'ospedale'
#   datetime.datetime(2020, 11, 27, 12, 41)
#   datetime.datetime(2020, 11, 27, 13, 6)]
#  [161 111 'ospedale' 'stazione' datetime.datetime(2020, 11, 27, 12, 58)
#   datetime.datetime(2020, 11, 27, 13, 31)]
#  [66 16 'medaglie d’oro' 'stazione'
#   datetime.datetime(2020, 11, 27, 13, 5)
#   datetime.datetime(2020, 11, 27, 13, 16)]
#  [79 29 'ospedale' 'medaglie d’oro'
#   datetime.datetime(2020, 11, 27, 13, 13)
#   datetime.datetime(2020, 11, 27, 13, 46)]
#  [85 35 'stazione' 'medaglie d’oro'
#   datetime.datetime(2020, 11, 27, 13, 15)
#   datetime.datetime(2020, 11, 27, 13, 26)]
#  [62 22 'p. dante' 'kennedy' datetime.datetime(2020, 11, 27, 13, 20)
#   datetime.datetime(2020, 11, 27, 13, 32)]
#  [103 53 'stazione' 'ospedale' datetime.datetime(2020, 11, 27, 13, 30)
#   datetime.datetime(2020, 11, 27, 13, 33)]
#  [70 30 'medaglie d’oro' 'stazione'
#   datetime.datetime(2020, 11, 27, 13, 49)
#   datetime.datetime(2020, 11, 27, 14, 0)]
#  [62 12 'medaglie d’oro' 'stazione'
#   datetime.datetime(2020, 11, 27, 14, 5)
#   datetime.datetime(2020, 11, 27, 14, 16)]
#  [104 54 'cavour giardini' 'ospedale'
#   datetime.datetime(2020, 11, 27, 14, 20)
#   datetime.datetime(2020, 11, 27, 14, 53)]
#  [62 12 'medaglie d’oro' 'stazione'
#   datetime.datetime(2020, 11, 27, 14, 20)
#   datetime.datetime(2020, 11, 27, 14, 31)]
#  [76 36 'kennedy' 'stazione' datetime.datetime(2020, 11, 27, 14, 23)
#   datetime.datetime(2020, 11, 27, 14, 39)]
#  [79 29 'stazione' 'medaglie d’oro '
#   datetime.datetime(2020, 11, 27, 14, 30)
#   datetime.datetime(2020, 11, 27, 14, 41)]
#  [77 27 'medaglie d’oro' 'stazione'
#   datetime.datetime(2020, 11, 27, 14, 50)
#   datetime.datetime(2020, 11, 27, 15, 1)]
#  [64 14 'ospedale' 'medaglie d’oro'
#   datetime.datetime(2020, 11, 27, 14, 58)
#   datetime.datetime(2020, 11, 27, 15, 20)]
#  [70 20 'stazione' 'medaglie d’oro'
#   datetime.datetime(2020, 11, 27, 15, 15)
#   datetime.datetime(2020, 11, 27, 15, 26)]
#  [65 15 'ospedale' 'medaglie d’oro'
#   datetime.datetime(2020, 11, 27, 15, 58)
#   datetime.datetime(2020, 11, 27, 16, 20)]
#  [74 24 'stazione' 'medaglie d’oro'
#   datetime.datetime(2020, 11, 27, 16, 45)
#   datetime.datetime(2020, 11, 27, 17, 18)]
#  [78 28 'medaglie d’oro' 'stazione'
#   datetime.datetime(2020, 11, 27, 16, 50)
#   datetime.datetime(2020, 11, 27, 17, 1)]
#  [72 32 'medaglie d’oro' 'stazione'
#   datetime.datetime(2020, 11, 27, 17, 19)
#   datetime.datetime(2020, 11, 27, 17, 30)]
#  [72 22 'medaglie d’oro' 'stazione'
#   datetime.datetime(2020, 11, 27, 17, 20)
#   datetime.datetime(2020, 11, 27, 17, 31)]
#  [104 54 'ospedale' 'stazione' datetime.datetime(2020, 11, 27, 17, 23)
#   datetime.datetime(2020, 11, 27, 18, 1)]
#  [90 40 'stazione ' 'kennedy' datetime.datetime(2020, 11, 28, 6, 54)
#   datetime.datetime(2020, 11, 28, 7, 1)]
#  [63 13 'kennedy' 'canapa' datetime.datetime(2020, 11, 28, 7, 10)
#   datetime.datetime(2020, 11, 28, 7, 24)]
#  [78 38 'stazione' 'barlaam' datetime.datetime(2020, 11, 28, 7, 15)
#   datetime.datetime(2020, 11, 28, 7, 22)]
#  [63 13 'stazione' 'kennedy' datetime.datetime(2020, 11, 28, 7, 21)
#   datetime.datetime(2020, 11, 28, 7, 29)]
#  [79 29 'barco' 'barriera' datetime.datetime(2020, 11, 28, 7, 26)
#   datetime.datetime(2020, 11, 28, 7, 36)]
#  [107 57 'kennedy ' 'canapa' datetime.datetime(2020, 11, 28, 7, 27)
#   datetime.datetime(2020, 11, 28, 7, 42)]
#  [81 31 'cavour giardini' 'malborghetto'
#   datetime.datetime(2020, 11, 28, 7, 30)
#   datetime.datetime(2020, 11, 28, 8, 0)]
#  [118 68 'smm' 'p. dante' datetime.datetime(2020, 11, 28, 7, 30)
#   datetime.datetime(2020, 11, 28, 7, 50)]
#  [77 27 'smm' 'p. dante' datetime.datetime(2020, 11, 28, 7, 33)
#   datetime.datetime(2020, 11, 28, 7, 53)]
#  [69 19 'kennedy' 'p. dante' datetime.datetime(2020, 11, 28, 7, 35)
#   datetime.datetime(2020, 11, 28, 7, 50)]
#  [67 17 'barriera' 'cavour giardini'
#   datetime.datetime(2020, 11, 28, 7, 36)
#   datetime.datetime(2020, 11, 28, 7, 40)]
#  [97 47 'stazione' 'pontegradella itis'
#   datetime.datetime(2020, 11, 28, 7, 37)
#   datetime.datetime(2020, 11, 28, 7, 51)]
#  [81 31 'autostazione' 'pontegradella iris'
#   datetime.datetime(2020, 11, 28, 7, 37)
#   datetime.datetime(2020, 11, 28, 7, 53)]
#  [94 44 'autostazione' 'pontegradella itis'
#   datetime.datetime(2020, 11, 28, 7, 38)
#   datetime.datetime(2020, 11, 28, 7, 54)]
#  [118 68 'stazione' 'pontegradella itis'
#   datetime.datetime(2020, 11, 28, 7, 40)
#   datetime.datetime(2020, 11, 28, 7, 54)]
#  [102 52 'stazione' 'pontegradella itis'
#   datetime.datetime(2020, 11, 28, 7, 40)
#   datetime.datetime(2020, 11, 28, 7, 54)]
#  [97 47 'barriera' 'pontegradella itis'
#   datetime.datetime(2020, 11, 28, 7, 41)
#   datetime.datetime(2020, 11, 28, 7, 52)]
#  [137 87 'stazione' 'kennedy' datetime.datetime(2020, 11, 28, 7, 42)
#   datetime.datetime(2020, 11, 28, 7, 50)]
#  [140 90 'stazione' 'pontegradella itis'
#   datetime.datetime(2020, 11, 28, 7, 42)
#   datetime.datetime(2020, 11, 28, 7, 56)]
#  [100 50 'medaglie d’oro' 'cavour giardini'
#   datetime.datetime(2020, 11, 28, 7, 43)
#   datetime.datetime(2020, 11, 28, 7, 49)]
#  [89 39 'stazione' 'pontegradella' datetime.datetime(2020, 11, 28, 7, 43)
#   datetime.datetime(2020, 11, 28, 7, 57)]
#  [80 30 'stazione' 'pontegradella iris'
#   datetime.datetime(2020, 11, 28, 7, 44)
#   datetime.datetime(2020, 11, 28, 7, 58)]
#  [80 30 'stazione' 'pontegradella iris'
#   datetime.datetime(2020, 11, 28, 7, 45)
#   datetime.datetime(2020, 11, 28, 7, 59)]
#  [63 13 'stazione' 'pontegradella iris'
#   datetime.datetime(2020, 11, 28, 7, 45)
#   datetime.datetime(2020, 11, 28, 8, 0)]
#  [60 10 'autostazione' 'malborghetto'
#   datetime.datetime(2020, 11, 28, 7, 45)
#   datetime.datetime(2020, 11, 28, 8, 10)]
#  [111 61 'stazione' 'cavour giardini'
#   datetime.datetime(2020, 11, 28, 7, 45)
#   datetime.datetime(2020, 11, 28, 7, 52)]
#  [86 36 'stazione' 'pontegradella itis'
#   datetime.datetime(2020, 11, 28, 7, 46)
#   datetime.datetime(2020, 11, 28, 8, 0)]
#  [90 40 'autostazione' 'p. dante' datetime.datetime(2020, 11, 28, 7, 47)
#   datetime.datetime(2020, 11, 28, 7, 57)]
#  [82 32 'stazione' 'p. dante' datetime.datetime(2020, 11, 28, 7, 47)
#   datetime.datetime(2020, 11, 28, 7, 53)]
#  [95 45 'stazione' 'canapa' datetime.datetime(2020, 11, 28, 7, 47)
#   datetime.datetime(2020, 11, 28, 7, 54)]
#  [75 25 'stazione' 'pontegradella iris'
#   datetime.datetime(2020, 11, 28, 7, 48)
#   datetime.datetime(2020, 11, 28, 8, 2)]
#  [60 10 'medaglie d’oro' 'stazione'
#   datetime.datetime(2020, 11, 28, 7, 49)
#   datetime.datetime(2020, 11, 28, 8, 0)]
#  [68 28 'stazione ' 'barlaam' datetime.datetime(2020, 11, 28, 7, 50)
#   datetime.datetime(2020, 11, 28, 7, 57)]
#  [143 93 'stazione' 'canapa' datetime.datetime(2020, 11, 28, 7, 50)
#   datetime.datetime(2020, 11, 28, 7, 57)]
#  [81 31 'stazione' 'p. dante' datetime.datetime(2020, 11, 28, 7, 50)
#   datetime.datetime(2020, 11, 28, 7, 56)]
#  [71 21 'autostazione' 'p. dante' datetime.datetime(2020, 11, 28, 7, 50)
#   datetime.datetime(2020, 11, 28, 8, 55)]
#  [70 20 'stazione' 'canapa' datetime.datetime(2020, 11, 28, 7, 51)
#   datetime.datetime(2020, 11, 28, 7, 58)]
#  [63 13 'stazione' 'p. dante' datetime.datetime(2020, 11, 28, 7, 52)
#   datetime.datetime(2020, 11, 28, 7, 58)]
#  [113 63 'stazione' 'corti medoro' datetime.datetime(2020, 11, 28, 7, 53)
#   datetime.datetime(2020, 11, 28, 8, 16)]
#  [65 15 'stazione' 'pontegradella itis'
#   datetime.datetime(2020, 11, 28, 7, 53)
#   datetime.datetime(2020, 11, 28, 8, 7)]
#  [109 59 'kennedy' 'canapa' datetime.datetime(2020, 11, 28, 7, 57)
#   datetime.datetime(2020, 11, 28, 8, 12)]
#  [110 60 'stazione ' 'medaglie d’oro'
#   datetime.datetime(2020, 11, 28, 8, 0)
#   datetime.datetime(2020, 11, 28, 8, 11)]
#  [92 42 'barriera' 'kennedy' datetime.datetime(2020, 11, 28, 8, 13)
#   datetime.datetime(2020, 11, 28, 8, 20)]
#  [95 45 'stazione' 'kennedy' datetime.datetime(2020, 11, 28, 8, 44)
#   datetime.datetime(2020, 11, 28, 8, 52)]
#  [75 25 'kennedy' 'stazione' datetime.datetime(2020, 11, 28, 9, 12)
#   datetime.datetime(2020, 11, 28, 9, 20)]
#  [73 23 'barriera' 'kennedy' datetime.datetime(2020, 11, 28, 9, 13)
#   datetime.datetime(2020, 11, 28, 9, 20)]
#  [70 20 'stazione' 'corti medoro' datetime.datetime(2020, 11, 28, 9, 57)
#   datetime.datetime(2020, 11, 28, 10, 20)]
#  [60 10 'stazione' 'kennedy' datetime.datetime(2020, 11, 28, 10, 12)
#   datetime.datetime(2020, 11, 28, 10, 20)]
#  [63 13 'stazione' 'kennedy' datetime.datetime(2020, 11, 28, 10, 42)
#   datetime.datetime(2020, 11, 28, 10, 50)]
#  [70 20 'barriera' 'kennedy' datetime.datetime(2020, 11, 28, 11, 13)
#   datetime.datetime(2020, 11, 28, 11, 20)]
#  [62 12 'corti di medoro' 'stazione'
#   datetime.datetime(2020, 11, 28, 11, 39)
#   datetime.datetime(2020, 11, 28, 12, 5)]
#  [69 19 'kennedy' 'stazione' datetime.datetime(2020, 11, 28, 11, 42)
#   datetime.datetime(2020, 11, 28, 11, 50)]
#  [66 16 'barriera' 'kennedy' datetime.datetime(2020, 11, 28, 11, 43)
#   datetime.datetime(2020, 11, 28, 11, 50)]
#  [124 74 'kennedy' 'stazione' datetime.datetime(2020, 11, 28, 12, 12)
#   datetime.datetime(2020, 11, 28, 12, 20)]
#  [74 24 'stazione' 'corti medoro' datetime.datetime(2020, 11, 28, 12, 27)
#   datetime.datetime(2020, 11, 28, 12, 50)]
#  [116 66 'kennedy' 'smm ' datetime.datetime(2020, 11, 28, 12, 42)
#   datetime.datetime(2020, 11, 28, 13, 13)]
#  [156 106 'canapa' 'barriera' datetime.datetime(2020, 11, 28, 13, 3)
#   datetime.datetime(2020, 11, 28, 13, 13)]
#  [69 19 'corti di medoro' 'stazione'
#   datetime.datetime(2020, 11, 28, 13, 11)
#   datetime.datetime(2020, 11, 28, 13, 37)]
#  [110 60 'kennedy' 'stazione' datetime.datetime(2020, 11, 28, 13, 12)
#   datetime.datetime(2020, 11, 28, 13, 20)]
#  [85 35 'medaglie d’oro' 'stazione'
#   datetime.datetime(2020, 11, 28, 13, 14)
#   datetime.datetime(2020, 11, 28, 13, 25)]
#  [68 18 'canapa' 'stazione' datetime.datetime(2020, 11, 28, 13, 15)
#   datetime.datetime(2020, 11, 28, 13, 22)]
#  [121 71 'pontegradella itis' 'stazione'
#   datetime.datetime(2020, 11, 28, 13, 15)
#   datetime.datetime(2020, 11, 28, 13, 29)]
#  [67 17 'medaglie d’oro' 'stazione'
#   datetime.datetime(2020, 11, 28, 13, 15)
#   datetime.datetime(2020, 11, 28, 13, 26)]
#  [68 28 'p. dante' 'stazione' datetime.datetime(2020, 11, 28, 13, 16)
#   datetime.datetime(2020, 11, 28, 13, 23)]
#  [95 45 'canapa' 'barriera' datetime.datetime(2020, 11, 28, 13, 16)
#   datetime.datetime(2020, 11, 28, 13, 26)]
#  [103 53 'p. dante' 'stazione' datetime.datetime(2020, 11, 28, 13, 16)
#   datetime.datetime(2020, 11, 28, 13, 22)]
#  [80 30 'p. dante' 'stazione' datetime.datetime(2020, 11, 28, 13, 18)
#   datetime.datetime(2020, 11, 28, 13, 24)]
#  [70 20 'p. dante' 'stazione' datetime.datetime(2020, 11, 28, 13, 18)
#   datetime.datetime(2020, 11, 28, 13, 24)]
#  [64 14 'pontegradella itis' 'autostazione'
#   datetime.datetime(2020, 11, 28, 13, 18)
#   datetime.datetime(2020, 11, 28, 13, 33)]
#  [112 62 'p. dante' 'smm' datetime.datetime(2020, 11, 28, 13, 25)
#   datetime.datetime(2020, 11, 28, 13, 45)]
#  [72 22 'corti di medoro' 'stazione'
#   datetime.datetime(2020, 11, 28, 13, 39)
#   datetime.datetime(2020, 11, 28, 14, 5)]
#  [78 28 'kennedy' 'stazione' datetime.datetime(2020, 11, 28, 13, 42)
#   datetime.datetime(2020, 11, 28, 13, 50)]
#  [85 35 'cavour giardini' 'stazione'
#   datetime.datetime(2020, 11, 28, 13, 43)
#   datetime.datetime(2020, 11, 28, 13, 49)]
#  [60 10 'canapa' 'barriera' datetime.datetime(2020, 11, 28, 13, 48)
#   datetime.datetime(2020, 11, 28, 13, 58)]
#  [75 25 'malborghetto' 'cavour giardini'
#   datetime.datetime(2020, 11, 28, 13, 58)
#   datetime.datetime(2020, 11, 28, 14, 20)]
#  [92 42 'canapa' 'kennedy' datetime.datetime(2020, 11, 28, 14, 3)
#   datetime.datetime(2020, 11, 28, 14, 20)]
#  [85 35 'giovecca montebello' 'stazione'
#   datetime.datetime(2020, 11, 28, 14, 5)
#   datetime.datetime(2020, 11, 28, 14, 15)]
#  [63 13 'malborghetto' 'kennedy' datetime.datetime(2020, 11, 28, 14, 5)
#   datetime.datetime(2020, 11, 28, 14, 30)]
#  [60 10 'malborghetto' 'stazione' datetime.datetime(2020, 11, 28, 14, 5)
#   datetime.datetime(2020, 11, 28, 14, 30)]
#  [70 20 'corti di medoro' 'stazione'
#   datetime.datetime(2020, 11, 28, 14, 9)
#   datetime.datetime(2020, 11, 28, 14, 35)]
#  [80 30 'medaglie d’oro' 'stazione'
#   datetime.datetime(2020, 11, 28, 14, 9)
#   datetime.datetime(2020, 11, 28, 14, 20)]
#  [80 30 'barlaam' 'stazione' datetime.datetime(2020, 11, 28, 14, 9)
#   datetime.datetime(2020, 11, 28, 14, 16)]
#  [136 86 'kennedy ' 'stazione' datetime.datetime(2020, 11, 28, 14, 12)
#   datetime.datetime(2020, 11, 28, 14, 20)]
#  [85 35 'pontegradella itis' 'cavour giardini'
#   datetime.datetime(2020, 11, 28, 14, 13)
#   datetime.datetime(2020, 11, 28, 14, 23)]
#  [69 19 'canapa' 'stazione' datetime.datetime(2020, 11, 28, 14, 14)
#   datetime.datetime(2020, 11, 28, 14, 21)]
#  [91 41 'pontegradella itis' 'stazione'
#   datetime.datetime(2020, 11, 28, 14, 14)
#   datetime.datetime(2020, 11, 28, 14, 28)]
#  [70 20 'p. dante' 'autostazione' datetime.datetime(2020, 11, 28, 14, 15)
#   datetime.datetime(2020, 11, 28, 14, 30)]
#  [90 40 'medaglie d’oro' 'autostazione'
#   datetime.datetime(2020, 11, 28, 14, 15)
#   datetime.datetime(2020, 11, 28, 14, 30)]
#  [74 24 'canapa' 'stazione' datetime.datetime(2020, 11, 28, 14, 16)
#   datetime.datetime(2020, 11, 28, 14, 23)]
#  [124 74 'cavour giardini' 'stazione'
#   datetime.datetime(2020, 11, 28, 14, 23)
#   datetime.datetime(2020, 11, 28, 14, 29)]
#  [90 40 'stazione' 'corti medoro' datetime.datetime(2020, 11, 28, 14, 27)
#   datetime.datetime(2020, 11, 28, 14, 35)]
#  [67 17 'kennedy' 'stazione' datetime.datetime(2020, 11, 28, 14, 42)
#   datetime.datetime(2020, 11, 28, 14, 50)]
#  [64 14 'stazione' 'kennedy' datetime.datetime(2020, 11, 28, 14, 42)
#   datetime.datetime(2020, 11, 28, 14, 50)]
#  [71 21 'kennedy' 'stazione' datetime.datetime(2020, 11, 28, 15, 12)
#   datetime.datetime(2020, 11, 28, 15, 20)]
#  [67 17 'stazione' 'kennedy' datetime.datetime(2020, 11, 28, 15, 12)
#   datetime.datetime(2020, 11, 28, 15, 20)]
#  [61 11 'stazione' 'corti di medoro'
#   datetime.datetime(2020, 11, 28, 15, 27)
#   datetime.datetime(2020, 11, 28, 15, 50)]
#  [90 40 'kennedy' 'stazione' datetime.datetime(2020, 11, 28, 15, 42)
#   datetime.datetime(2020, 11, 28, 15, 50)]
#  [67 17 'stazione' 'corti di medoro'
#   datetime.datetime(2020, 11, 28, 15, 57)
#   datetime.datetime(2020, 11, 28, 16, 20)]
#  [97 47 'kennedy' 'stazione' datetime.datetime(2020, 11, 28, 16, 12)
#   datetime.datetime(2020, 11, 28, 16, 20)]
#  [60 10 'stazione' 'kennedy' datetime.datetime(2020, 11, 28, 16, 12)
#   datetime.datetime(2020, 11, 28, 16, 20)]
#  [71 21 'stazione' 'kennedy' datetime.datetime(2020, 11, 28, 16, 27)
#   datetime.datetime(2020, 11, 28, 16, 35)]
#  [84 34 'corti medoro' 'stazione' datetime.datetime(2020, 11, 28, 16, 39)
#   datetime.datetime(2020, 11, 28, 17, 5)]
#  [87 37 'stazione' 'kennedy' datetime.datetime(2020, 11, 28, 16, 42)
#   datetime.datetime(2020, 11, 28, 16, 50)]
#  [71 21 'kennedy' 'stazione' datetime.datetime(2020, 11, 28, 16, 42)
#   datetime.datetime(2020, 11, 28, 16, 50)]
#  [77 27 'corti di medoro' 'stazione'
#   datetime.datetime(2020, 11, 28, 17, 9)
#   datetime.datetime(2020, 11, 28, 17, 35)]
#  [88 38 'kennedy ' 'stazione' datetime.datetime(2020, 11, 28, 17, 12)
#   datetime.datetime(2020, 11, 28, 17, 20)]
#  [76 26 'stazione' 'kennedy' datetime.datetime(2020, 11, 28, 17, 12)
#   datetime.datetime(2020, 11, 28, 17, 20)]
#  [67 17 'corti di medoro' 'stazione'
#   datetime.datetime(2020, 11, 28, 17, 39)
#   datetime.datetime(2020, 11, 28, 18, 5)]
#  [84 34 'kennedy' 'stazione' datetime.datetime(2020, 11, 28, 17, 42)
#   datetime.datetime(2020, 11, 28, 17, 50)]
#  [77 27 'kennedy' 'stazione' datetime.datetime(2020, 11, 28, 18, 12)
#   datetime.datetime(2020, 11, 28, 18, 20)]
#  [69 19 'kennedy' 'stazione' datetime.datetime(2020, 11, 28, 18, 42)
#   datetime.datetime(2020, 11, 28, 18, 50)]]

# %%
import pandas as pd
import numpy as np
import mip
from datetime import datetime
#from Demos.win32console_demo import z


# <<<<<<<<<<<<<  header  >>>>>>>>>>>>>>>

# definizioni costanti fittizzie


COUNTED_PASSENGERS = 0
EXTRA_PASSENGERS = 1
INITIAL_STOP = 2
FINAL_STOP = 3
INITIAL_TIME = 4
FINAL_TIME = 5

K_AUTOBUS = 10

# lettura files

Tratte = pd.read_excel('file di dati.xls', sheet_name="porzioni di viaggio")
tempi_vuoto = pd.read_excel("file di dati.xls", sheet_name="tempi di percorrenza a vuoto")

# i tempi a vuoto sono una matrice triangolare inferiore in cui gli elementi [0][j] sono i nomi delle partenze e
# gli elementi [i][0] le destinazioni. Quindi gli elementi [i][j] rappresentano il tempo per andare a vuoto dalla origine
# j alla destinazione i

# conversione files

Tratte = Tratte.to_numpy()
tempi_vuoto = tempi_vuoto.to_numpy()

# testings

timedelay = Tratte[1][5] - Tratte[1][4]

n_di_tratte = Tratte.shape

#converte i tempi di partenza in millisec from 1970
for i in range(n_di_tratte[0]):
    if i!=0:
        Tratte[i][INITIAL_TIME] = datetime.timestamp(Tratte[i][INITIAL_TIME])

#converte i tempi di arrivo in millisec from 1970
for i in range(n_di_tratte[0]):
    if i!=0:
        Tratte[i][FINAL_TIME] = datetime.timestamp(Tratte[i][FINAL_TIME])
        print(Tratte[i][FINAL_TIME])


print(Tratte[1][4])
print(timedelay)
print(n_di_tratte[0])
print(f"Da {tempi_vuoto[2][0]} a {tempi_vuoto[0][4]} il tempo di percorrenza è {tempi_vuoto[4][2]} minuti ")


# <<<<<<<<<<<<< Modello mip >>>>>>>>>>>>>

modello = mip.Model()

x = np.array([modello.add_var(var_type=mip.BINARY) for i in range(0,n_di_tratte[0]*K_AUTOBUS)])
z = np.array([modello.add_var(var_type=mip.INTEGER) for i in range(0,K_AUTOBUS)])

dimensionex = x.shape
dimensionez = z.shape
print(f"la dimensione della x è {dimensionex} e della z {dimensionez}")


#for j in range(0,K_AUTOBUS):
 #   z[j] = modello.add_var(var_type=mip.INTEGER)

#for j in range(0,K_AUTOBUS):
#    for i in range(1,n_di_tratte[0]):
#        modello.add_constr(xij*(Tratte[i][INITIAL_STOP]))


#m.objective = mip.maximize(110*x1 + 130*x2)

#scansiona tutte le tratte disponibili
"""
j=0
for i in range(0,157*K_AUTOBUS):
    if i != 0:
        modello.add_constr(x[i]*Tratte[i][INITIAL_TIME]>=x[i]*(z[j]+Tratte[i][FINAL_TIME])) #prende i primi 157 slot di i
    if i/157 == j+1:
        j=j+1


for i in range(0,157*K_AUTOBUS):
    print(x[i])
"""



#m.add_constr(  x1 + 2*x2 <= 10)
#m.add_constr(2*x1 + 2*x2 <= 18)
#m.add_constr(  x1 + 3*x2 <= 12)
#m.add_constr(2*x1 + 3*x2 <= 21)
#m.add_constr(  x1        <=  9)
#m.add_constr(  x1        <= 10)
# Out:
# 1606458060.0
# 1606458900.0
# 1606459080.0
# 1606460280.0
# 1606459560.0
# 1606459440.0
# 1606459560.0
# 1606459860.0
# 1606460460.0
# 1606460460.0
# 1606460760.0
# 1606463160.0
# 1606463580.0
# 1606464180.0
# 1606463760.0
# 1606465980.0
# 1606467180.0
# 1606468680.0
# 1606469460.0
# 1606473180.0
# 1606474200.0
# 1606475760.0
# 1606476660.0
# 1606478760.0
# 1606480260.0
# 1606479360.0
# 1606481160.0
# 1606479960.0
# 1606480320.0
# 1606480380.0
# 1606482000.0
# 1606482960.0
# 1606485180.0
# 1606483860.0
# 1606484340.0
# 1606484460.0
# 1606485660.0
# 1606486800.0
# 1606487160.0
# 1606490400.0
# 1606493880.0
# 1606492860.0
# 1606494600.0
# 1606494660.0
# 1606496460.0
# 1606543260.0
# 1606544640.0
# 1606544520.0
# 1606544940.0
# 1606545360.0
# 1606545720.0
# 1606546800.0
# 1606546200.0
# 1606546380.0
# 1606546200.0
# 1606545600.0
# 1606546260.0
# 1606546380.0
# 1606546440.0
# 1606546440.0
# 1606546440.0
# 1606546320.0
# 1606546200.0
# 1606546560.0
# 1606546140.0
# 1606546620.0
# 1606546680.0
# 1606546740.0
# 1606546800.0
# 1606547400.0
# 1606546320.0
# 1606546800.0
# 1606546620.0
# 1606546380.0
# 1606546440.0
# 1606546920.0
# 1606546800.0
# 1606546620.0
# 1606546620.0
# 1606546560.0
# 1606550100.0
# 1606546680.0
# 1606546680.0
# 1606547760.0
# 1606547220.0
# 1606547520.0
# 1606547460.0
# 1606548000.0
# 1606549920.0
# 1606551600.0
# 1606551600.0
# 1606555200.0
# 1606555200.0
# 1606557000.0
# 1606558800.0
# 1606561500.0
# 1606560600.0
# 1606560600.0
# 1606562400.0
# 1606564200.0
# 1606565580.0
# 1606565580.0
# 1606567020.0
# 1606566000.0
# 1606566300.0
# 1606566120.0
# 1606566540.0
# 1606566360.0
# 1606566180.0
# 1606566360.0
# 1606566120.0
# 1606566240.0
# 1606566240.0
# 1606566780.0
# 1606567500.0
# 1606568700.0
# 1606567800.0
# 1606567740.0
# 1606568280.0
# 1606569600.0
# 1606569600.0
# 1606569300.0
# 1606570200.0
# 1606570200.0
# 1606570500.0
# 1606569600.0
# 1606569360.0
# 1606569600.0
# 1606569780.0
# 1606569660.0
# 1606570080.0
# 1606570200.0
# 1606570200.0
# 1606569780.0
# 1606570140.0
# 1606570500.0
# 1606571400.0
# 1606571400.0
# 1606573200.0
# 1606573200.0
# 1606575000.0
# 1606575000.0
# 1606576800.0
# 1606576800.0
# 1606576800.0
# 1606577700.0
# 1606579500.0
# 1606578600.0
# 1606578600.0
# 1606581300.0
# 1606580400.0
# 1606580400.0
# 1606583100.0
# 1606582200.0
# 1606584000.0
# 1606585800.0
# 1606457400.0
# 0:11:00
# 157
# Da kennedy a canapa il tempo di percorrenza è 15 minuti
# la dimensione della x è (1570,) e della z (10,)
# '\nj=0\nfor i in range(0,157*K_AUTOBUS):\n    if i != 0:\n        modello.add_constr(x[i]*Tratte[i][INITIAL_TIME]>=x[i]*(z[j]+Tratte[i][FINAL_TIME])) #prende i primi 157 slot di i\n    if i/157 == j+1:\n        j=j+1\n\n\nfor i in range(0,157*K_AUTOBUS):\n    print(x[i])\n'
